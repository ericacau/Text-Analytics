# %%
# Read in the data and clean up column names
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import accuracy_score, f1_score
from sklearn import model_selection, svm
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
df = pd.read_csv("books_def.csv", index_col=0).reset_index()
df = df[(df['genres'] == 'Fiction') | (df['genres'] == 'Nonfiction')]
df = df.reset_index()
del df['index']

# %%
df
# Out:
#                                    book_authors  \
# 0                                     Dan Brown
# 1                                 Arthur Golden
# 2                 Oscar Wilde|Jeffrey Eugenides
# 3      Paulo Coelho|Alan R. Clarke|Özdemir İnce
# 4                              Kathryn Stockett
# ...                                         ...
# 13613                             Siri Hustvedt
# 13614                             Avi Steinberg
# 13615                             Howard Megdal
# 13616                             Howard Megdal
# 13617                    Mimi Baird|Eve Claxton
#
#                                                book_desc  book_rating  \
# 0      An ingenious code hidden in the works of Leona...         3.81
# 1      A literary sensation and runaway bestseller, t...         4.09
# 2      ﻿Written in his distinctively dazzling manner,...         4.06
# 3      Paulo Coelho's masterpiece tells the mystical ...         3.84
# 4      Be prepared to meet three unforgettable women:...         4.46
# ...                                                  ...          ...
# 13613  A brilliant, provocative novel about an artist...         3.67
# 13614  Avi Steinberg is stumped. After defecting from...         3.51
# 13615  In this fearless and half-crazy story, Howard ...         3.37
# 13616  From the icons of the game to the players who ...         3.97
# 13617  Soon to be a major motion picture, from Brad P...         3.82
#
#                                               book_title      genres
# 0                                      The Da Vinci Code     Fiction
# 1                                    Memoirs of a Geisha     Fiction
# 2                             The Picture of Dorian Gray     Fiction
# 3                                          The Alchemist     Fiction
# 4                                               The Help     Fiction
# ...                                                  ...         ...
# 13613                                  The Blazing World     Fiction
# 13614  Running the Books: The Adventures of an Accide...  Nonfiction
# 13615  Taking the Field: A Fan's Quest to Run the Tea...  Nonfiction
# 13616  The Baseball Talmud: Koufax, Greenberg, and th...  Nonfiction
# 13617  He Wanted the Moon: The Madness and Medical Ge...  Nonfiction
#
# [13618 rows x 5 columns]

# %%
# Clean data using  built in cleaner in gensim
df['text_clean'] = df['book_desc'].apply(lambda x: gensim.utils.simple_preprocess(x))
df
# Out:
#                                    book_authors  \
# 0                                     Dan Brown
# 1                                 Arthur Golden
# 2                 Oscar Wilde|Jeffrey Eugenides
# 3      Paulo Coelho|Alan R. Clarke|Özdemir İnce
# 4                              Kathryn Stockett
# ...                                         ...
# 13613                             Siri Hustvedt
# 13614                             Avi Steinberg
# 13615                             Howard Megdal
# 13616                             Howard Megdal
# 13617                    Mimi Baird|Eve Claxton
#
#                                                book_desc  book_rating  \
# 0      An ingenious code hidden in the works of Leona...         3.81
# 1      A literary sensation and runaway bestseller, t...         4.09
# 2      ﻿Written in his distinctively dazzling manner,...         4.06
# 3      Paulo Coelho's masterpiece tells the mystical ...         3.84
# 4      Be prepared to meet three unforgettable women:...         4.46
# ...                                                  ...          ...
# 13613  A brilliant, provocative novel about an artist...         3.67
# 13614  Avi Steinberg is stumped. After defecting from...         3.51
# 13615  In this fearless and half-crazy story, Howard ...         3.37
# 13616  From the icons of the game to the players who ...         3.97
# 13617  Soon to be a major motion picture, from Brad P...         3.82
#
#                                               book_title      genres  \
# 0                                      The Da Vinci Code     Fiction
# 1                                    Memoirs of a Geisha     Fiction
# 2                             The Picture of Dorian Gray     Fiction
# 3                                          The Alchemist     Fiction
# 4                                               The Help     Fiction
# ...                                                  ...         ...
# 13613                                  The Blazing World     Fiction
# 13614  Running the Books: The Adventures of an Accide...  Nonfiction
# 13615  Taking the Field: A Fan's Quest to Run the Tea...  Nonfiction
# 13616  The Baseball Talmud: Koufax, Greenberg, and th...  Nonfiction
# 13617  He Wanted the Moon: The Madness and Medical Ge...  Nonfiction
#
#                                               text_clean
# 0      [an, ingenious, code, hidden, in, the, works, ...
# 1      [literary, sensation, and, runaway, bestseller...
# 2      [written, in, his, distinctively, dazzling, ma...
# 3      [paulo, coelho, masterpiece, tells, the, mysti...
# 4      [be, prepared, to, meet, three, unforgettable,...
# ...                                                  ...
# 13613  [brilliant, provocative, novel, about, an, art...
# 13614  [avi, steinberg, is, stumped, after, defecting...
# 13615  [in, this, fearless, and, half, crazy, story, ...
# 13616  [from, the, icons, of, the, game, to, the, pla...
# 13617  [soon, to, be, major, motion, picture, from, b...
#
# [13618 rows x 6 columns]

# %%
i = 0
g_dict = {}
for g in df.genres.unique():
    g_dict[g] = i
    i=i+1

# %%
# Encoding the label column
df['genres']=df['genres'].map(g_dict)
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split (df['text_clean'], df['genres'] , test_size=0.3)

# %%
# Train the word2vec model
w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=300,
                                   window=10,
                                   min_count=2)

# %%
words = set(w2v_model.wv.index_to_key)
X_train_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_train])
X_test_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_test])
# Out:
# <ipython-input-10-a03581770919>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_train_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
# <ipython-input-10-a03581770919>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_test_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
X_train_vect_avg = []
for v in X_train_vect:
    if v.size:
        X_train_vect_avg.append(v.mean(axis=0))
    else:
        X_train_vect_avg.append(np.zeros(100, dtype=float))
        
X_test_vect_avg = []
for v in X_test_vect:
    if v.size:
        X_test_vect_avg.append(v.mean(axis=0))
    else:
        X_test_vect_avg.append(np.zeros(100, dtype=float))

# %%
# Instantiate and fit a basic Random Forest model on top of the vectors
rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect_avg, y_train.values.ravel())
y_pred = rf_model.predict(X_test_vect_avg)

print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Testing accuracy 0.8225648556045032
# Testing F1 score: 0.8221651129846815

# %%
logreg = LogisticRegression(n_jobs=1, C=1e5, max_iter=1000000)
logreg.fit(X_train_vect_avg, y_train.values.ravel())

y_pred = logreg.predict(X_test_vect_avg)

print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Testing accuracy 0.8749388154674498
# Testing F1 score: 0.8749205520045532
# /Users/federico/miniforge3/envs/tf/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
SVM = svm.SVC()
SVM.fit(X_train_vect_avg, y_train.values.ravel())

y_pred = SVM.predict(X_test_vect_avg)

print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Testing accuracy 0.8414096916299559
# Testing F1 score: 0.8413306055353243
